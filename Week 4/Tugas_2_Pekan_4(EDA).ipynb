# %% [markdown]
# # Soal 1: Pemahaman Teori
# Jelaskan perbedaan antara Univariate, Bivariate dan Multivariate Analysis

# %% [markdown]
# Jawaban:

# %% [markdown]
# Univariate Analysis merupakan sebuah teknik dalam memahami dan melakukan eksplorasi data. Imbuhan awal ‘Uni’ artinya ‘satu’, maka analisa univariate merupakan analisa data feature tunggal.
#
# ---
# Bivariate analysis digunakan untuk untuk menganalisa 2 variables dan menemukan sebuah relasi. Analisis bivariate juga merupakan salah satu cara untuk menggunakan koefisien korelasi dalam rangka menemukan apakah dua variabel memiliki relasi atau tidak.
#
#
# ---
# Multivariate analysis digunakan untuk menganalisa lebih dari 2 variabel di waktu yang sama, trends yang dihasilkan bisa menjadi multidimensi secara alami, dengan analisa ini akan membantu kita memahami manakah data yang memiliki tren yang kompleks pada kombinasi atribut.
#
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 2. Persiapan Data
#
# *   Hapus nilai missing dalam rows dataset menggunakan atribut.dropna()
#
# *   Lakukan grouping data berdasarkan kolom 'species' dengan menggunakan agregasi mean()

# %%
#code here
df.dropna(inplace=True)
df2 = df.groupby(['species']).mean()
df2
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie          38.823973      18.347260         190.102740  3706.164384
# Chinstrap       48.833824      18.420588         195.823529  3733.088235
# Gentoo          47.568067      14.996639         217.235294  5092.436975

# %% [markdown]
# Expected output:
#
# ![tanpa handling missing value](https://drive.google.com/uc?id=1OnuXmscVRqduqT_TYI1vB291rpXM4D_1)

# %% [markdown]
# # Soal 3. Univariate Analysis
# Buatlah sebuah analisa univariate dengan menggunakan perintah seperti berikut:
#
# *   Buatlah sebuah Pie plot dari dataset hasil grouping untuk kolom flipper_length_mm seperti expected output berikut:
# *   Buatlah sebuah plot histogram dari dataset awal (sebelum grouping) untuk kolom body_mass_g
# *   Jelaskan insight yang diperoleh dari ke dua grafik tersebut.

# %%
#code here
fig = plt.figure(figsize=(12,8))
plt.pie(df2['flipper_length_mm'], labels = list(df2.index.values), autopct='%1.1f%%')
plt.title('Pie Chart')

fig2 = plt.figure(figsize=(10,7))
plt.hist(x=df['body_mass_g'])
plt.title('Histogram')
plt.xlabel('Body_mass_g')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Expected Output:
#
#
# Pie Chart
#
# ![](https://drive.google.com/uc?id=11H6X7xpEeodPWD56tHBhV4sLrJ-6B-Bd)
#
# Histogram
#
# ![](https://drive.google.com/uc?id=1A_twS7BbQhkGvUz7zAWgye7q3ZRTQkhi)

# %% [markdown]
# Analisa:

# %% [markdown]
# Dari Pie chart tersebut kita dapat melihat persentase rata-rata nilai 'flipper_length_mm' masing-masing species dari total rata-rata semua species.
#
# ---
#
# Dari Histogram tersebut kita dapat mengetahui pada range berapa 'Body_mass_g' mempunyai frekuensi tertinggi dan terendah. Frekuensi tertinggi berada pada range sekitar 3400 - 3700 g, sedangkan frekuensi terendah berada pada range >6000 g.
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 4. Bivariate Analysis
#
#
#
# *   Buatlah sebuah grafik catplot menggunakan seaborn dengan x='sex', y='bill_length_mm' dan kind 'bar' seperti expected output di bawah
# *   Buatlah sebuah grafik scatter plot menggunakan seaborn dengan x='body_mass_g', y='flipper_length_mm', hue='bill_length_mm' seperti expected dibawah
# *   Jelaskan insight yang diperoleh dari hasil analisa bivariate tersebut

# %%
#code here
plt.figure(figsize=(12,8))
sns.catplot(x='sex', y='bill_length_mm', kind='bar', data=df)
plt.title('Catplot')

plt.figure(figsize=(12,8))
sns.scatterplot(x='body_mass_g', y='flipper_length_mm', hue='bill_length_mm', data=df)
plt.title('Scatterplot')

plt.show()

# %% [markdown]
# Expected Output:
#
# Catplot
#
# ![](https://drive.google.com/uc?id=1imCbGD9cWqXUjd33tAh6D0OH20vVpWea)
#
# Scatter plot
#
# ![](https://drive.google.com/uc?id=1_k734IpRYq6Q1wF57hwzSEjnVd2Sii2Z)

# %% [markdown]
# Analisa:

# %% [markdown]
# Dari catplot diatas dapat diketahui range nilai 'bill_length_mm' untuk data Male dan female. Dapat diketahui juga nilai 'bill_length_mm' tertinggi Male lebih tinggi dari female.
#
# ---
#
# Dari scatterplot diatas dapat dilihat bahwa hubungan 'body_mass_g' dengan 'flipper_length_mm' berbanding lurus karena semakin tinggi 'body_mass_g' semakin tinggi pula nilai 'flipper_length_mm'. Dapat dilihat variabel 'body_mass_g' dengan 'flipper_length_mm' mempunyai korelasi positif yang kuat.
#
# ---
#
#
#
# ---

# %% [markdown]
# # Soal 5. Multivariate Analisis
#
# *   Dengan menggunakan seaborn, buatlah sebuah pairplot keseluruhan data feature pada dataset (df) dengan argumen kind='bar', seperti expected di bawah:
# *   Jelaskan hasil analisa dari multivariate yang dihasilkan

# %%
#code here
sns.pairplot(df, diag_kind='hist')

# %% [markdown]
# Expected output:
#
# Pair plot
#
# ![](https://drive.google.com/uc?id=1td8WAZLJEW5BPTq-wEJyZ4soRNNLXfqX)

# %% [markdown]
# Analisa:

# %% [markdown]
# Dari visualisasi data diatas kita dapat melihat hubungan antara setiap variabel pada dataset yang kita gunakan. Contohnya hubungan antara flipper_length_mm dengan body_mass_g yang berbanding lurus atau berkorelasi positif. Diagram bar pada sel diagonal menunjukkan konsentrasi data yaitu pada range berapakah suatu frekuensi data paling banyak dan sedikit.
#
# ---
#
#
#
# ---
#
#
#
# ---
